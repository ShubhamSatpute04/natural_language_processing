# %%
# seq to seq model is ml algo fot task involving sequential data 
# i/p seq ----->o/p seq
# encoder and decoder
# seq2seq imroves quality of ml algo and make them as imp technology

# %%
# Encoder takes the input seq and process into
