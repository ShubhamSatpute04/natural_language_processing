# %%
'''
Transformers:
-noval architecture aim to solve sequence to sequence task while handling long-range dependencies with ease 
-its first teansduction model relying entirely on self-attention to compute representation of its inpute and 
output without using sequence aligned RNNs ot convolution
- tranduction means conversion of input sequences into output seqns.
- to handle dependencies between
'''
