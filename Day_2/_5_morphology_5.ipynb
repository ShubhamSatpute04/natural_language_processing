# %%
from polyglot.text import Word
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from polyglot.text import Word
#
# ModuleNotFoundError: No module named 'polyglot'

# %%
words=['cats','computing','association','programming','leadership','miscommunication','indentifiable','psychologically','engineering','tabular','realistic','colorfuleness','blackboard','sunflower','dashboard']

# %%
for w in words:
    w= Word(w,language='en')
    print(w,'\t',w.morphemes)
# Out:
# cats 	 ['cat', 's']
# computing 	 ['com', 'put', 'ing']
# association 	 ['associ', 'ation']
# programming 	 ['program', 'ming']
# leadership 	 ['leader', 'ship']
# miscommunication 	 ['mis', 'communication']
# indentifiable 	 ['in', 'd', 'ent', 'ifi', 'able']
# psychologically 	 ['psycho', 'logical', 'ly']
# engineering 	 ['engine', 'er', 'ing']
# tabular 	 ['tab', 'ular']
# realistic 	 ['real', 'istic']
# colorfuleness 	 ['color', 'ful', 'e', 'ness']
# blackboard 	 ['black', 'board']
# sunflower 	 ['s', 'un', 'flower']
# dashboard 	 ['d', 'ash', 'board']

# %%
# Other than English word

# %%
mwords=["राज्यशास्त्र",    "जलविद्युत",    "महाद्वीप",    "मानसशास्त्र" ,   "अर्थशास्त्र",    "अर्थसंकल्प",    "भांडवलशाही",
    "समाजवाद",    "महसूल",    "चलनवाढ",    "गुंतवणूक",    "उत्पादन",    "ग्राहकोपयोगी",    "करप्रणाली"
]

# %%
for w in mwords:
    w= Word(w,language='mr')
    print(w,'\t',w.morphemes)
# Out:
# राज्यशास्त्र 	 ['राज्य', 'शास्त्र']
# जलविद्युत 	 ['जल', 'विद्युत']
# महाद्वीप 	 ['महा', 'द्वीप']
# मानसशास्त्र 	 ['मानस', 'शास्त्र']
# अर्थशास्त्र 	 ['अर्थ', 'शास्त्र']
# अर्थसंकल्प 	 ['अर्थ', 'संकल्प']
# भांडवलशाही 	 ['भांडवल', 'शाही']
# समाजवाद 	 ['समाज', 'वाद']
# महसूल 	 ['महसूल']
# चलनवाढ 	 ['चलन', 'वाढ']
# गुंतवणूक 	 ['गुंत', 'वणूक']
# उत्पादन 	 ['उत्पादन']
# ग्राहकोपयोगी 	 ['ग्राहक', 'ोपयोगी']
# करप्रणाली 	 ['कर', 'प्रणाली']
