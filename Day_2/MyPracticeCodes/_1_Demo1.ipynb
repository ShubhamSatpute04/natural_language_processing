# %%
# 1. Basic Tokenization
# Write a program to tokenize a paragraph into words and sentences using NLTK.
para='''पुणे (अंग्रेज़ी: Pune) भारत के महाराष्ट्र राज्य का एक महत्त्वपूर्ण शहर है। पुणे भारत का छठवां सबसे बड़ा शहर व महाराष्ट्र का दूसरा सबसे बड़ा शहर है।.[5] यह शहर महाराष्ट्र के पश्चिम भाग, मुला व मुठा इन दो नदियों के किनारे बसा है और पुणे जिला का प्रशासकीय मुख्यालय है। सार्वजनिक सुखसुविधा व विकास के हिसाब से पुणे महाराष्ट्र मे मुंबई के बाद अग्रसर है। [6][7])अनेक नामांकित शिक्षणसंस्थायें होने के कारण इस शहर को 'पूरब का ऑक्सफोर्ड' भी कहा जाता है। पुणे में अनेक प्रौद्योगिकी और ऑटोमोबाईल उपक्रम हैं, इसलिए पुणे भारत का ”डेट्राइट” जैसा लगता है। काफी प्राचीन ज्ञात इतिहास से पुणे शहर महाराष्ट्र की 'सांस्कृतिक राजधानी' माना जाता है। मराठी भाषा इस शहर की मुख्य भाषा है।

पुणे शहर मे लगभग सभी विषयों के उच्च शिक्षण की सुविधा उपलब्ध है। पुणे विद्यापीठ, राष्ट्रीय रासायनिक प्रयोगशाला, आयुका, आगरकर संशोधन संस्था, सी-डैक जैसी आन्तरराष्ट्रीय स्तर के शिक्षण संस्थान यहाँ है। पुणे फिल्म इन्स्टिट्युट भी काफी प्रसिद्ध है।

पुणे महाराष्ट्र व भारत का एक महत्त्वपूर्ण औद्योगिक केन्द्र है। टाटा मोटर्स, बजाज ऑटो, भारत फोर्ज जैसे उत्पादनक्षेत्र के अनेक बड़े उद्योग यहाँ है। 1990 के दशक मे इन्फोसिस, टाटा कंसल्टंसी सर्विसे, विप्रो, सिमैंटेक, आईबीएम जैसे प्रसिद्ध सॉफ्टवेअर कंपनियों ने पुणे मे अपने केन्द्र खोले और यह शहर भारत का एक प्रमुख सूचना प्रौद्योगिकी उद्योगकेन्द्र के रूप मे विकसित हुआ।

2024 में पुणे की अनुमानित जनसंख्या 10,480,787 है |[8]'''
from nltk.tokenize import word_tokenize
words=[word for word in word_tokenize(para)]
words
# Out:
# ['पुणे',
#  '(',
#  'अंग्रेज़ी',
#  ':',
#  'Pune',
#  ')',
#  'भारत',
#  'के',
#  'महाराष्ट्र',
#  'राज्य',
#  'का',
#  'एक',
#  'महत्त्वपूर्ण',
#  'शहर',
#  'है।',
#  'पुणे',
#  'भारत',
#  'का',
#  'छठवां',
#  'सबसे',
#  'बड़ा',
#  'शहर',
#  'व',
#  'महाराष्ट्र',
#  'का',
#  'दूसरा',
#  'सबसे',
#  'बड़ा',
#  'शहर',
#  'है।',
#  '.',
#  '[',
#  '5',
#  ']',
#  'यह',
#  'शहर',
#  'महाराष्ट्र',
#  'के',
#  'पश्चिम',
#  'भाग',
#  ',',
#  'मुला',
#  'व',
#  'मुठा',
#  'इन',
#  'दो',
#  'नदियों',
#  'के',
#  'किनारे',
#  'बसा',
#  'है',
#  'और',
#  'पुणे',
#  'जिला',
#  'का',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'है।',
#  'सार्वजनिक',
#  'सुखसुविधा',
#  'व',
#  'विकास',
#  'के',
#  'हिसाब',
#  'से',
#  'पुणे',
#  'महाराष्ट्र',
#  'मे',
#  'मुंबई',
#  'के',
#  'बाद',
#  'अग्रसर',
#  'है।',
#  '[',
#  '6',
#  ']',
#  '[',
#  '7',
#  ']',
#  ')',
#  'अनेक',
#  'नामांकित',
#  'शिक्षणसंस्थायें',
#  'होने',
#  'के',
#  'कारण',
#  'इस',
#  'शहर',
#  'को',
#  "'",
#  'पूरब',
#  'का',
# ...

# %%
# 2. Text Cleaning Pipeline
sents='''Pune (Marathi: Puṇē, pronounced [ˈpuɳe] ⓘ), previously spelled in English as Poona (the official name until 1978),[16][17] is a city in the state of Maharashtra in the Deccan Plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. In terms of the total amount of land under its jurisdiction, Pune is the largest city in Maharashtra by area, with a geographical area of 516.18km2,[18] though by population it comes in a distant second to Mumbai. According to the 2011 Census of India, Pune has 7.2 million residents in the metropolitan region, making it the seventh-most populous metropolitan area in India.[19] The city of Pune is part of Pune Metropolitan Region.[20] Pune is one of the largest IT hubs in India.[21][22] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions.[23][24][25] It has been ranked "the most liveable city in India" several times.[26][27]

Pune at different points in time has been ruled by the Rashtrakuta dynasty, Ahmadnagar Sultanate, the Mughals, and the Adil Shahi dynasty. In the 18th century, the city was part of the Maratha Empire, and the seat of the Peshwas, the prime ministers of the Maratha Empire.[28] Pune was seized by the British East India Company in the Third Anglo-Maratha War; it gained municipal status in 1858, the year in which Crown rule began. Many historical landmarks like Shaniwarwada, Shinde Chhatri, and Vishrambaug Wada date to this era. Historical sites from different eras dot the city.

Pune has historically been a major cultural centre, with important figures like Dnyaneshwar, Shivaji, Tukaram, Baji Rao I, Balaji Baji Rao, Madhavrao I, Nana Fadnavis, Mahadev Govind Ranade, Gopal Krishna Gokhale, Mahatma Jyotirao Phule, Savitribai Phule, Gopal Ganesh Agarkar, Tarabai Shinde, Dhondo Keshav Karve, and Pandita Ramabai doing their life's work in Pune City or in an area that falls in Pune Metropolitan Region. Pune was a major centre of resistance to the British Raj, with people like Gopal Krishna Gokhale and Bal Gangadhar Tilak playing leading roles in the struggle for Indian independence.'''
# Given a paragraph, perform:

# tokenization
# lowercase conversion
# punctuation removal
from string import punctuation
# number removal
words = [word.lower() for word in word_tokenize(sents) if word not in punctuation and not word.isdigit() ]
# Print the cleaned tokens.
words
# Out:
# ['pune',
#  'marathi',
#  'puṇē',
#  'pronounced',
#  'ˈpuɳe',
#  'ⓘ',
#  'previously',
#  'spelled',
#  'in',
#  'english',
#  'as',
#  'poona',
#  'the',
#  'official',
#  'name',
#  'until',
#  'is',
#  'a',
#  'city',
#  'in',
#  'the',
#  'state',
#  'of',
#  'maharashtra',
#  'in',
#  'the',
#  'deccan',
#  'plateau',
#  'in',
#  'western',
#  'india',
#  'it',
#  'is',
#  'the',
#  'administrative',
#  'headquarters',
#  'of',
#  'the',
#  'pune',
#  'district',
#  'and',
#  'of',
#  'pune',
#  'division',
#  'in',
#  'terms',
#  'of',
#  'the',
#  'total',
#  'amount',
#  'of',
#  'land',
#  'under',
#  'its',
#  'jurisdiction',
#  'pune',
#  'is',
#  'the',
#  'largest',
#  'city',
#  'in',
#  'maharashtra',
#  'by',
#  'area',
#  'with',
#  'a',
#  'geographical',
#  'area',
#  'of',
#  '516.18km2',
#  'though',
#  'by',
#  'population',
#  'it',
#  'comes',
#  'in',
#  'a',
#  'distant',
#  'second',
#  'to',
#  'mumbai',
#  'according',
#  'to',
#  'the',
#  'census',
# ...

# %%
# 3. Stopword Removal
from nltk.corpus import stopwords
s_words=stopwords.words('english')
words = [word.lower() for word in words if word not in s_words]
# Remove English stopwords from a given text and print meaningful words.
words
# Out:
# ['pune',
#  'marathi',
#  'puṇē',
#  'pronounced',
#  'ˈpuɳe',
#  'ⓘ',
#  'previously',
#  'spelled',
#  'english',
#  'poona',
#  'official',
#  'name',
#  'city',
#  'state',
#  'maharashtra',
#  'deccan',
#  'plateau',
#  'western',
#  'india',
#  'administrative',
#  'headquarters',
#  'pune',
#  'district',
#  'pune',
#  'division',
#  'terms',
#  'total',
#  'amount',
#  'land',
#  'jurisdiction',
#  'pune',
#  'largest',
#  'city',
#  'maharashtra',
#  'area',
#  'geographical',
#  'area',
#  '516.18km2',
#  'though',
#  'population',
#  'comes',
#  'distant',
#  'second',
#  'mumbai',
#  'according',
#  'census',
#  'india',
#  'pune',
#  '7.2',
#  'million',
#  'residents',
#  'metropolitan',
#  'region',
#  'making',
#  'seventh-most',
#  'populous',
#  'metropolitan',
#  'area',
#  'india',
#  'city',
#  'pune',
#  'part',
#  'pune',
#  'metropolitan',
#  'region',
#  'pune',
#  'one',
#  'largest',
#  'hubs',
#  'india',
#  'also',
#  'one',
#  'important',
# ...

# %%
# 4. Word Frequency Analysis
# After cleaning a paragraph, find the top 10 most frequent words.
count={}
for word in words:
       count[word]=count.get(word,0)+1

# %%
# 5. POS Tagging
from nltk.tag import pos_tag
# Tokenize a sentence and assign POS tags using NLTK's pos_tag().
tags = pos_tag(words)
tags[1]
# Out:
# ('marathi', 'NN')

# %%
# 6. Noun Extraction
# Extract all nouns (NN, NNS, NNP, NNPS) from a paragraph.
noun_words = [tag for tag in tags if tag[1].startswith('NN')]
noun_words
# Out:
# [('pune', 'NN'),
#  ('marathi', 'NN'),
#  ('puṇē', 'NN'),
#  ('ˈpuɳe', 'NNP'),
#  ('ⓘ', 'NNP'),
#  ('poona', 'NN'),
#  ('official', 'NN'),
#  ('name', 'NN'),
#  ('city', 'NN'),
#  ('state', 'NN'),
#  ('plateau', 'NN'),
#  ('india', 'NNP'),
#  ('headquarters', 'NNS'),
#  ('district', 'NN'),
#  ('pune', 'NN'),
#  ('division', 'NN'),
#  ('terms', 'NNS'),
#  ('amount', 'NN'),
#  ('land', 'NN'),
#  ('jurisdiction', 'NN'),
#  ('city', 'NN'),
#  ('area', 'NN'),
#  ('area', 'NN'),
#  ('population', 'NN'),
#  ('mumbai', 'NN'),
#  ('census', 'NN'),
#  ('india', 'NN'),
#  ('residents', 'NNS'),
#  ('region', 'NN'),
#  ('area', 'NN'),
#  ('city', 'NN'),
#  ('part', 'NN'),
#  ('pune', 'NN'),
#  ('region', 'NN'),
#  ('hubs', 'NN'),
#  ('india', 'NN'),
#  ('automobile', 'NN'),
#  ('manufacturing', 'NN'),
#  ('hubs', 'NN'),
#  ('india', 'NN'),
#  ('pune', 'NN'),
#  ('oxford', 'NN'),
#  ('east', 'NN'),
#  ('institutions', 'NNS'),
#  ('city', 'NN'),
#  ('india', 'NN'),
#  ('times', 'NNS'),
# ...

# %%
# 7. Adjective–Noun Pair Detection
# Identify all adjective-noun combinations occurring consecutively in a text.
adj_noun_words =[]
for i,tag in enumerate(tags):
    if tag[1].startswith('JJ') and tags[i+1][1].startswith('NN'):
        adj_noun_words.append([tag[0],tag[1],tags[i+1][0],tags[i+1][1]])
adj_noun_words
# Out:
# [['english', 'JJ', 'poona', 'NN'],
#  ['deccan', 'JJ', 'plateau', 'NN'],
#  ['western', 'JJ', 'india', 'NNP'],
#  ['administrative', 'JJ', 'headquarters', 'NNS'],
#  ['total', 'JJ', 'amount', 'NN'],
#  ['largest', 'JJS', 'city', 'NN'],
#  ['maharashtra', 'JJ', 'area', 'NN'],
#  ['geographical', 'JJ', 'area', 'NN'],
#  ['second', 'JJ', 'mumbai', 'NN'],
#  ['metropolitan', 'JJ', 'region', 'NN'],
#  ['metropolitan', 'JJ', 'area', 'NN'],
#  ['metropolitan', 'JJ', 'region', 'NN'],
#  ['largest', 'JJS', 'hubs', 'NN'],
#  ['important', 'JJ', 'automobile', 'NN'],
#  ['educational', 'JJ', 'institutions', 'NNS'],
#  ['liveable', 'JJ', 'city', 'NN'],
#  ['several', 'JJ', 'times', 'NNS'],
#  ['different', 'JJ', 'points', 'NNS'],
#  ['dynasty', 'JJ', 'ahmadnagar', 'NN'],
#  ['18th', 'JJ', 'century', 'NN'],
#  ['prime', 'JJ', 'ministers', 'NNS'],
#  ['india', 'JJ', 'company', 'NN'],
#  ['anglo-maratha', 'JJ', 'war', 'NN'],
#  ['municipal', 'JJ', 'status', 'NN'],
# ...

# %%
# for porper noun capital start letter is considered
# Extract pairs of consecutive proper nouns.
from nltk.corpus import stopwords
s_words=stopwords.words('english')
from string import punctuation
proper_nouns_pair=[]
words= [word for word in word_tokenize(sents) if word not in s_words and word not in punctuation]
tags= pos_tag(words)
for i,tag in enumerate(tags):
    if tag[1].startswith('NNP') and tags[i+1][1].startswith('NNP'):
        proper_nouns_pair.append([tag,'  :  ',tags[i+1]])
proper_nouns_pair
# Out:
# [[('Pune', 'NNP'), '  :  ', ('Marathi', 'NNP')],
#  [('Marathi', 'NNP'), '  :  ', ('Puṇē', 'NNP')],
#  [('ˈpuɳe', 'NNP'), '  :  ', ('ⓘ', 'NNP')],
#  [('English', 'NNP'), '  :  ', ('Poona', 'NNP')],
#  [('Maharashtra', 'NNP'), '  :  ', ('Deccan', 'NNP')],
#  [('Deccan', 'NNP'), '  :  ', ('Plateau', 'NNP')],
#  [('Plateau', 'NNP'), '  :  ', ('Western', 'NNP')],
#  [('Western', 'NNP'), '  :  ', ('India', 'NNP')],
#  [('Census', 'NNP'), '  :  ', ('India', 'NNP')],
#  [('India', 'NNP'), '  :  ', ('Pune', 'NNP')],
#  [('Pune', 'NNP'), '  :  ', ('Metropolitan', 'NNP')],
#  [('Metropolitan', 'NNP'), '  :  ', ('Region', 'NNP')],
#  [('India', 'NNP'), '  :  ', ('Pune', 'NNP')],
#  [('Oxford', 'NNP'), '  :  ', ('East', 'NNP')],
#  [('Ahmadnagar', 'NNP'), '  :  ', ('Sultanate', 'NNP')],
#  [('Sultanate', 'NNP'), '  :  ', ('Mughals', 'NNP')],
#  [('Mughals', 'NNP'), '  :  ', ('Adil', 'NNP')],
#  [('Adil', 'NNP'), '  :  ', ('Shahi', 'NNP')],
#  [('Maratha', 'NNP'), '  :  ', ('Empire', 'NNP')],
# ...

# %%
# 9. POS Distribution Analysis
# Count the frequency of each POS tag in a paragraph and display the results.
count={}
for tag in tags:
    count[tag[1]]=count.get(tag[1],0)+1
print(count)
# Out:
# {'NNP': 106, 'VBD': 8, 'RB': 4, 'NN': 40, 'CD': 21, 'PRP': 5, 'JJ': 28, 'NNS': 12, 'IN': 6, 'JJS': 2, 'VBZ': 4, 'VBG': 4, 'DT': 1, '``': 2, "''": 2, 'VBP': 1, 'POS': 1}

# %%
# 10. Corpus Exploration

# Print:

# available files in Indian Corpus
print(pos_tag.__dir__)
# number of sentences

# number of tagged words in each file
# Out:
# <built-in method __dir__ of function object at 0x0000027889AD9D00>

# %%
# 11. Marathi Corpus Processing
# Load marathi.pos and print the first 20 sentences without their tags.
from nltk.corpus import indian
print(indian.fileids())
print(indian.tagged_sents()[:20])
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'telugu.pos']
# ...

# %%
# 12. POS Tag Statistics in Indian Corpus
# Calculate the frequency of each POS tag in marathi.pos
from nltk import TnT
from nltk.corpus import indian
tagger=TnT()
tags=indian.tagged_sents('marathi.pos')
tagger.train(tags)
tagger.tag(word_tokenize(para))
new_sent='''पुण्यातील हवामान आज खूपच सुंदर असून, विद्यार्थी सकाळी लवकर उठून कॉलेजला जात आहेत आणि रस्त्यावर वाहतूक नेहमीप्रमाणे चालू आहे.'''
tagger.tag(word_tokenize(new_sent))
# Out:
# [('पुण्यातील', 'NNP'),
#  ('हवामान', 'Unk'),
#  ('आज', 'NN'),
#  ('खूपच', 'Unk'),
#  ('सुंदर', 'Unk'),
#  ('असून', 'VAUX'),
#  (',', 'SYM'),
#  ('विद्यार्थी', 'NN'),
#  ('सकाळी', 'NN'),
#  ('लवकर', 'RB'),
#  ('उठून', 'Unk'),
#  ('कॉलेजला', 'Unk'),
#  ('जात', 'VAUX'),
#  ('आहेत', 'VAUX'),
#  ('आणि', 'CC'),
#  ('रस्त्यावर', 'NN'),
#  ('वाहतूक', 'NNC'),
#  ('नेहमीप्रमाणे', 'Unk'),
#  ('चालू', 'JJ'),
#  ('आहे', 'VM'),
#  ('.', 'SYM')]

# %%
# 13. Train a TnT POS Tagger

# Train a TnT tagger using hindi.pos and test it on a new Hindi sentence.

# 14. TnT Accuracy Evaluation

# Split a tagged corpus into:

# 80% training
# 20% testing

# Calculate POS tagging accuracy.

# 15. Porter Stemming

# Apply Porter Stemmer on a list of words and display original vs stemmed words.

# 16. Porter vs Lancaster Comparison

# Compare outputs of Porter and Lancaster stemmers for the same word list.

# 17. Lemmatization

# Use WordNetLemmatizer to convert verbs into their base forms.

# Example:

# running → run
# ate → eat
# 18. Stemming vs Lemmatization Analysis

# For a paragraph:

# stem all words
# lemmatize all words

# Compare the outputs and count how many words changed under each technique.

# 19. Morphological Analysis with Polyglot

# For a list of English and Marathi words:

# extract morphemes
# count morphemes
# display results in tabular form
# 20. Mini NLP Project

# Build a complete NLP preprocessing pipeline that:

# tokenizes text
# removes punctuation
# removes stopwords
# performs stemming
# performs POS tagging
# extracts nouns
# displays top 5 frequent words

# Input should be taken from the user.
