# %%
# %pip install nltk spacy textblob
'''* **NLTK** is used for basic natural language processing tasks like tokenizing and analyzing text.
* **spaCy** is used for fast, production-level NLP tasks like named entity recognition and text parsing.
* **TextBlob** is used for simple NLP tasks like sentiment analysis and basic text processing with an easy API.
'''
# Out:
# '* **NLTK** is used for basic natural language processing tasks like tokenizing and analyzing text.\n* **spaCy** is used for fast, production-level NLP tasks like named entity recognition and text parsing.\n* **TextBlob** is used for simple NLP tasks like sentiment analysis and basic text processing with an easy API.\n'

# %%
# %pip install nltk spacy textblob -U
# upgrade (-U) the Python libraries

# %%
import nltk
# load the Natural Language Toolkit (NLTK)

# %%
# nltk.download()

# %%
# nltk.download('punkt')

# nltk.download('punkt_tab') 

# #tokenizer for tab separated text

# nltk.download('stopwords')
#  #stopwords are the most common words in a language that do not carry much meaning and are often removed from text data during preprocessing.

# nltk.download('averaged_perceptrom_tagger') 
# #The averaged_perceptron_tagger is a part-of-speech tagger that uses the averaged perceptron algorithm to assign part-of-speech tags to words in a sentence. It is a machine learning-based tagger that has been trained on a large corpus of text data and can accurately identify the grammatical categories of words, such as nouns, verbs, adjectives, etc.

# nltk.download('averaged_perceptrom_tagger_eng')
#  #The averaged_perceptron_tagger_eng is a specific version of the averaged_perceptron_tagger that is trained on English language data. It is designed to accurately tag English words with their corresponding part-of-speech tags, such as nouns, verbs, adjectives, etc. This tagger is commonly used in natural language processing tasks that involve English text data.

# nltk.download('wordnet') 
# #WordNet is a large lexical database of the English language that groups words into sets of synonyms called synsets. It provides a rich resource for natural language processing tasks, such as word sense disambiguation, semantic similarity, and information retrieval. WordNet includes information about the relationships between words, such as hypernyms (more general terms), hyponyms (more specific terms), and meronyms (part-whole relationships). It is widely used in various NLP applications and research.

# nltk.download('indian') 
#The 'indian' package in NLTK is a collection of resources and tools for processing Indian languages. It includes tokenizers, stemmers, and stopword lists for several Indian languages, such as Hindi, Bengali, Tamil, Telugu, and more. This package is useful for natural language processing tasks involving Indian languages, such as text preprocessing, tokenization, stemming, and stopword removal.

# nltk.download('omw-1.4')
 #The 'omw-1.4' package in NLTK stands for "Open Multilingual WordNet". It is a resource that provides multilingual wordnets for various languages, including English, Spanish, French, German, and more. The Open Multilingual WordNet is a collection of wordnets that are linked together, allowing for cross-lingual mapping of words and their meanings. This package is useful for natural language processing tasks that involve multiple languages and require access to wordnet resources in different languages.

# %%
# find avg of nums present in string
# using loop and split()
sent='They told that their ages are 24 31 and 29 respectively'
words=sent.split(' ')
avg=0
count=0
for l in words:
    if l.isdigit():
        avg += float(l)
        count+=1
avg=avg/count
print(avg)
# Out:
# 28.0

# %%
#using list comprehension 
sent='They told that their ages are 24 31 and 29 respectively'
ages=[int(word) for word in sent.split() if word.isdigit()]
sum(ages)/len(ages)
# Out:
# 28.0

# %%
# find avg of nums present in string
sent='They told that their ages are 24, 31 and 29 respectively'  #here coma is added so its assume 29 as string 
ages=[int(word) for word in sent.split() if word.isdigit()]
sum(ages)/len(ages)
# Out:
# 30.0

# %% [markdown]
# ### sentence tokenizer

# %%
# smallest unit in nlp is word

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
# to seperate the words or sentence, Now no need of using slice and slice cant seperate punctations also it can so that

# %%
sent='''Hello friends!
How are you?
Welcome to the worold of python Programing.'''

# %%
print(sent)
# Out:
# Hello friends!
# How are you?
# Welcome to the worold of python Programing.

# %%
sents=sent_tokenize(sent)  # seperate sentence from punctuation returns list of sentences

# %%
sents
# Out:
# ['Hello friends!',
#  'How are you?',
#  'Welcome to the worold of python Programing.']

# %%
print(sents[0])
print(sents[1])
print(sents[2])
# Out:
# Hello friends!
# How are you?
# Welcome to the worold of python Programing.

# %%
# sent='''The heavy, iron-wrought gate—weathered by decades of bitter, salty storms—creaked open with a sharp, piercing shriek; inside, the long-abandoned garden lay entirely cloaked in a thick, suffocating blanket of gray mist. "Is anyone there?" whispered Clara, her voice trembling slightly, though she already knew, deep down in her racing heart, that no living soul would answer her call. Shadows danced, leaped, and contorted across the cracked stone pathways, twisting themselves into grotesque, unrecognizable shapes that seemed to mimic old, forgotten nightmares. She took one step forward, then another, pausing briefly to listen—did she just hear a faint, rhythmic tapping against the glass of the greenhouse, or was it merely the wind? Rain began to fall in sudden, violent sheets (a relentless downpour that instantly soaked through her thin woolen coat), yet she refused to turn back now. Shadows grew longer; the air grew colder; the silence, ironically, became absolutely deafening. "Think, Clara, think!" she muttered fiercely to herself, desperately clutching the cold brass key tightly inside her pocket, her knuckles turning a stark, ghostly white. Suddenly—crack! A dry, brittle twig snapped violently somewhere in the darkness behind her, causing her to spin around so fast she nearly lost her footing on the slick, moss-covered ground. Nothing was visible through the gloom, nothing except the towering, skeletal silhouettes of dead oak trees. She gasped, her breath catching painfully in her throat; moreover, a strange, metallic scent began to waft through the damp night air. Why had she agreed to come to this godforsaken place, at midnight, completely alone? The old grandfather clock in the distant manor house began to chime—one, two, three heavy, reverberating strokes—echoing like a solemn, ominous warning. "Time's up," a low, gravelly voice hissed right into her ear, causing her heart to stop completely.'''
# sents=sent_tokenize(sent)
# sents

# %% [markdown]
# #### Tokenizer
# - to seperate based on some thing (prebuild) like word sentence

# %% [markdown]
# ### Word Tokenizer
# - seperates words
# - consider punctuations also

# %%
sents_word=word_tokenize(sent)
sents_word
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'the',
#  'worold',
#  'of',
#  'python',
#  'Programing',
#  '.']

# %%
#find % of punctuation symbol in sent
import string
# import string so you can find punctuations
punct=[]
for w in sents_word:
    if w in string.punctuation:
        punct.append(w)
(len(punct)/len(sents_word))*100
# Out:
# 20.0

# %%
count_punc=[word for word in sents_word if word in string.punctuation]
print(count_punc)
(len(count_punc)/len(sents_word))*100
# Out:
# ['!', '?', '.']
# 20.0

# %%
remove_punc=[word for word in sents_word if word not in string.punctuation]

# sencond way
new_str=''
for char in sent:
    if char not in string.punctuation:
        new_str+=char
new_str
# Out:
# 'Hello friends\nHow are you\nWelcome to the worold of python Programing'

# %%
str1='''पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]

पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.'''

# %%
print(str1)
# Out:
# पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]
#
# ...

# %%
# sents=sent_tokenize(str1)
# sents

# %%
word_sent=word_tokenize(str1)
word_sent
# Out:
# ['पुणे',
#  'हे',
#  'भारताच्या',
#  'दख्खन',
#  'पठारावरील',
#  'महाराष्ट्राचे',
#  'एक',
#  'महत्त्वाचे',
#  'शहर',
#  'आहे',
#  '.',
#  'पुणे',
#  'जिल्ह्याचे',
#  'आणि',
#  'पुणे',
#  'विभागाचे',
#  'हे',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'आहे',
#  '.',
#  '२०११',
#  'जनगणनेनुसार',
#  ',',
#  'शहराच्या',
#  'हद्दीतील',
#  '३.१',
#  'दशलक्ष',
#  'लोकसंख्येसह',
#  'पुणे',
#  'हे',
#  'भारतातील',
#  'नववे',
#  'सर्वात',
#  'जास्त',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  'महानगर',
#  'प्रदेशातील',
#  '७.२',
#  'दशलक्ष',
#  'रहिवासी',
#  'लोकसंख्या',
#  'आहे',
#  ',',
#  'यानुसार',
#  'ते',
#  'आठवे',
#  'सर्वाधिक',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '८',
#  ']',
#  'पुणे',
#  'शहर',
#  'पुणे',
#  'महानगर',
#  'प्रदेशाचा',
#  'एक',
#  'भाग',
#  'आहे',
#  '.',
#  '[',
#  '९',
#  ']',
#  'भारतातील',
#  'सर्वात',
#  'मोठ्या',
#  'आयटी',
#  'हबपैकी',
#  'पुणे',
#  'एक',
#  'आहे',
#  '.',
#  '[',
#  '१०',
#  ']',
#  '[',
#  '११',
# ...

# %%
new_sent='DR. Mrs. Kulkarni got ₹ 12 lakh salary.' # here it identifies which . is full stop which . is of name like Dr.
words=word_tokenize(new_sent)
words
# Out:
# ['DR.', 'Mrs.', 'Kulkarni', 'got', '₹', '12', 'lakh', 'salary', '.']

# %%
# open a file for reading
content= open("mydata.txt", "r").read()
print(content)
# Out:
# 12 abcd 15, 10
# 4, 9, 9, and 12 10
# 4.5, 11, 6.3 xyz

# %%
# toknize data and take numbers out
words=word_tokenize(content)
num=[float(num) for num in words if not num.isalpha() and num not in string.punctuation ]
sum(num)/len(num)
# Out:
# 9.345454545454546

# %% [markdown]
# ### White space tokenizer
# - toknize based on spaces means space tab and new line

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
wtk=WhitespaceTokenizer()

# %%
sent
# Out:
# 'Hello friends!\nHow are you?\nWelcome to the worold of python Programing.'

# %%
wtk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'the',
#  'worold',
#  'of',
#  'python',
#  'Programing.']

# %% [markdown]
# # Space tokenizer
# - only space is considered not other form of space like tab and new line

# %%
from nltk.tokenize import SpaceTokenizer

# %%
stk=SpaceTokenizer()

# %%
stk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!\nHow',
#  'are',
#  'you?\nWelcome',
#  'to',
#  'the',
#  'worold',
#  'of',
#  'python',
#  'Programing.']

# %%
sent='''Hello friends! How are you?
Welcome\tto the world of Python\tProgramming.'''

# %%
stk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?\nWelcome\tto',
#  'the',
#  'world',
#  'of',
#  'Python\tProgramming.']

# %% [markdown]
# # Tab tokenize

# %%
from nltk.tokenize import TabTokenizer
ttk=TabTokenizer()

# %%
ttk.tokenize(sent)
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %% [markdown]
# # Line Token

# %%
from nltk.tokenize import LineTokenizer
ltk=LineTokenizer()

# %%
ltk.tokenize(sent)
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %% [markdown]
# # space Tokenizer

# %%
from nltk.tokenize import SpaceTokenizer
stk=SpaceTokenizer()

# %%
stk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?\nWelcome\tto',
#  'the',
#  'world',
#  'of',
#  'Python\tProgramming.']

# %% [markdown]
# # multi word expression
# formultiple word togather

# %%
from nltk.tokenize import MWETokenizer

# %%
nsent='Chhatrpati Shivaji Maharaj was founder of maratha empire'

# %%
word_tokenize(nsent)
# Out:
# ['Chhatrpati',
#  'Shivaji',
#  'Maharaj',
#  'was',
#  'founder',
#  'of',
#  'maratha',
#  'empire']

# %%
# mwe=MWETokenizer()
mwe=MWETokenizer(separator=" ") #default seperaor is _ which is shown when words are joined

# %%
mwe.add_mwe(('Chhatrpati','Shivaji','Maharaj'))

# %%
mwe.tokenize(word_tokenize(nsent))
# Out:
# ['Chhatrpati Shivaji Maharaj', 'was', 'founder', 'of', 'maratha', 'empire']

# %% [markdown]
# # Tweet Tokenizer
# imogi uses unicode
# smilies are part of same develop by tweeter

# %% [markdown]
# pheonitic similarity used for translitratio

# %%
name='गणेश शेठ'

# %%
name.replace('ठ','ट')
# Out:
# 'गणेश शेट'

# %%
name.split()
# Out:
# ['गणेश', 'शेठ']

# %%
name.isascii()
# Out:
# False

# %%
name.index('श')
# Out:
# 3

# %%
len(name)
# Out:
# 8

# %%
char='\u092A'
char
# Out:
# 'प'

# %%
ord('प')
# Out:
# 2346

# %%
chr(2347)
# Out:
# 'फ'

# %% [markdown]
# # Emojies and smilies

# %%
sent='Hello Friends! :) How are you? Welcome to python <3Programing.'

# %%
from nltk.tokenize import TweetTokenizer

# %%
twtk=TweetTokenizer()

# %%
twtk.tokenize(sent)
# Out:
# ['Hello',
#  'Friends',
#  '!',
#  ':)',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'python',
#  '<3',
#  'Programing',
#  '.']

# %%
sent='Hello😀friends😃H😎w😍are,😘you 🫠'
sent
# Out:
# 'Hello😀friends😃H😎w😍are,😘you 🫠'

# %%
twtk.tokenize(sent)
# Out:
# ['Hello', '😀', 'friends', '😃', 'H', '😎', 'w', '😍', 'are', ',', '😘', 'you', '🫠']

# %% [markdown]
# # Custom Tokenizer
# - Own defined tokenizer for some custom seperations
# - mostly regex are used here for seperation or pattren matching

# %%
# to import regex
import re

# %%
# define our own custom toknizer function
def custom_tokenizer(text):
    return re.split(r"[.,;?!\s]+",text)

# %%
text="This.is some text with punctuation > let's tokenize it. Is it ok?"

# %%
custom_tokenizer(text)
# Out:
# ['This',
#  'is',
#  'some',
#  'text',
#  'with',
#  'punctuation',
#  '>',
#  "let's",
#  'tokenize',
#  'it',
#  'Is',
#  'it',
#  'ok',
#  '']

# %%
# define custom toknizer funtion inside a class
class CommaTokenizer:
    def tokenize(self,text):
        return re.split(r"[,\s]+",text)

# %%
tk=CommaTokenizer()
fruits='apple,orange,manigo,graphes.'
tk.tokenize(fruits)
# Out:
# ['apple', 'orange', 'manigo', 'graphes.']
