# %% [markdown]
# ## SEmantic Parsing :
# - understand deeper meaning of word
# - what who what whome is determined
# - there are diffrent formats or way of saying same sentence so find its same or diffrent

# %%
import urllib
