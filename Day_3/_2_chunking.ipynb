# %% [markdown]
# # Chunking
# + return graphical output
# + To identify noun phareses or noun or any part of speech
# + pos (part of speech)-
# + to check syntax of sentence or gramatically is it correct
# + pos tagging based on combination
# ### Chunking Up -
# + for chunking based on
# ### Chunkig Down -
# + for chunking based on

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag,RegexpParser

# %%
sent='It was a beautifuak game by him. An amazing play was witnessed.'

# %%
grammer="NP:{<DT><JJ><NN>}"

# %%
parser=RegexpParser(grammer)

# %%
tree=parser.parse(pos_tag(word_tokenize(sent)))

# %%
# %pip install svgling

# %%
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('beautifuak', 'JJ'), ('game', 'NN')]), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('was', 'VBD'), ('witnessed', 'VBN'), ('.', '.')])

# %%
'''grammer=r"NP:{<DT><JJ><NN>}"
+ <DT>? Zero or more Determiner
+ <JJ>* Zero or more  adjectives
+ <NN>+ one or more nouns '''
# Out:
# 'grammer=r"NP:{<DT><JJ><NN>}"\n+ <DT>? Zero or more Determiner\n+ <JJ>* Zero or more  adjectives\n+ <NN>+ one or more nouns '

# %%
sent='''It was a beautifuak game by him. 
An amazing play was witnessed. They wom the game.'''
parser=RegexpParser(grammer)
tree=parser.parse(pos_tag(word_tokenize(sent)))
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('beautifuak', 'JJ'), ('game', 'NN')]), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('was', 'VBD'), ('witnessed', 'VBN'), ('.', '.'), ('They', 'PRP'), ('wom', 'VBP'), ('the', 'DT'), ('game', 'NN'), ('.', '.')])

# %%
from nltk import ne_chunk
import nltk
# nltk.download('ne_chunk')

# %%
sent='Mark Zuekberg is CEO of Meta at California'

# %%
tree=ne_chunk(pos_tag(word_tokenize(sent)))
tree
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tree=ne_chunk(pos_tag(word_tokenize(sent)))
#       2 tree
#
# File c:\Users\PGCP-AI\AppData\Local\anaconda3\Lib\site-packages\nltk\chunk\__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File c:\Users\PGCP-AI\AppData\Local\anaconda3\Lib\site-packages\nltk\chunk\__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
#     172     Load NLTK's currently recommended named entity chunker.
#     173     """
# --> 174     return Maxent_NE_Chunker(fmt)
#
# File c:\Users\PGCP-AI\AppData\Local\anaconda3\Lib\site-packages\nltk\chunk\named_entity.py:328, in Maxent_NE_Chunker.__init__(self, fmt)
# ...
